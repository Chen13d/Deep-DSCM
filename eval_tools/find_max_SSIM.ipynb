# %%
from find_max_SSIM import *

        
if __name__ == "__main__":
    if 1:
        read_dir = r'D:\CQL\codes\microscopy_decouple\evaluation\DSRM\DSRM_synthetic_data\MAE_SSIM.csv'
        save_dir = r'D:\CQL\codes\microscopy_decouple\evaluation\DSRM\DSRM_synthetic_data\MAE_SSIM_sta.csv'
        name_list = [
            'mae_micro_micro_lyso', 'mae_lyso_micro_lyso', 'SSIM_micro_micro_lyso', 'SSIM_lyso_micro_lyso', 'mae_micro_lyso', 'SSIM_micro_lyso', 
            'mae_mito_mito_lyso', 'mae_lyso_mito_lyso', 'SSIM_mito_mito_lyso', 'SSIM_lyso_mito_lyso', 'mae_mito_lyso', 'SSIM_mito_lyso', 
            'mae_micro_micro_mito', 'mae_mito_micro_mito', 'SSIM_micro_micro_mito', 'SSIM_mito_micro_mito', 'mae_micro_mito', 'SSIM_micro_mito', 
            'mae_micro_micro_mito_lyso', 'mae_mito_micro_mito_lyso', 'mae_lyso_micro_mito_lyso', 'SSIM_micro_micro_mito_lyso', 'SSIM_mito_micro_mito_lyso', 'SSIM_lyso_micro_mito_lyso', 'mae_micro_mito_lyso', 'SSIM_micro_mito_lyso', 
            'mae_NPCs_NPCs_mito_inner', 'mae_mito_inner_NPCs_mito_inner', 'SSIM_NPCS_NPCs_mito_inner', 'SSIM_mito_inner_NPCs_mito_inner', 'mae_NPCs_mito_inner', 'SSIM_NPCs_mito_inner', 
            'mae_NPCs_NPCs_membrane', 'mae_Membrane_NPCs_membrane', 'SSIM_NPCs_NPCs_membrane', 'SSIM_Membrane_NPCs_membrane', 'mae_NPCs_membrane', 'SSIM_NPCs_membrane', 
            'mae_mito_inner_mito_inner_membrane', 'mae_membrane_mito_inner_membrane', 'SSIM_mito_inner_mito_inner_membrane', 'SSIM_membrane_mito_inner_membrane', 'mae_mito_inner_membrane', 'SSIM_mito_inner_membrane', 
            'mae_NPCs_NPCs_mito_inner_membrane', 'mae_mito_inner_NPCs_mito_inner_membrane', 'mae_membrane_NPCs_mito_inner_membrane', 'SSIM_NPCs_NPCs_mito_inner_membrane', 'SSIM_mito_inner_NPCs_mito_inner_membrane', 'SSIM_membrane_NPCs_mito_inner_membrane', 'mae_NPCs_mito_inner_membrane', 'SSIM_NPCs_mito_inner_membrane', 
        ]
        df = find_max_SSIM(read_dir=read_dir, save_dir=save_dir, name_list=name_list)

        read_dir = r'D:\CQL\codes\microscopy_decouple\evaluation\DSRM\DSRM_synthetic_data'
        save_name_list = [
            'Micro_Lyso', 'Micro_Lyso', 'Micro_Lyso', 'Micro_Lyso', 'Micro_Lyso', 'Micro_Lyso', 
            'Mito_Lyso', 'Mito_Lyso', 'Mito_Lyso', 'Mito_Lyso', 'Mito_Lyso', 'Mito_Lyso', 
            'Micro_Mito', 'Micro_Mito', 'Micro_Mito', 'Micro_Mito', 'Micro_Mito', 'Micro_Mito', 
            'Micro_Mito_Lyso', 'Micro_Mito_Lyso', 'Micro_Mito_Lyso', 'Micro_Mito_Lyso', 'Micro_Mito_Lyso', 'Micro_Mito_Lyso', 'Micro_Mito_Lyso', 'Micro_Mito_Lyso', 
            'NPCs_Mito_inner', 'NPCs_Mito_inner', 'NPCs_Mito_inner', 'NPCs_Mito_inner', 'NPCs_Mito_inner', 'NPCs_Mito_inner', 
            'NPCs_Membrane', 'NPCs_Membrane', 'NPCs_Membrane', 'NPCs_Membrane', 'NPCs_Membrane', 'NPCs_Membrane', 
            'Mito_inner_Membrane', 'Mito_inner_Membrane', 'Mito_inner_Membrane', 'Mito_inner_Membrane', 'Mito_inner_Membrane', 'Mito_inner_Membrane', 
            'NPCs_Mito_inner_Membrane', 'NPCs_Mito_inner_Membrane', 'NPCs_Mito_inner_Membrane', 'NPCs_Mito_inner_Membrane', 'NPCs_Mito_inner_Membrane', 'NPCs_Mito_inner_Membrane', 'NPCs_Mito_inner_Membrane', 'NPCs_Mito_inner_Membrane', 
            ]
            
        for i in range(len(save_name_list)):
            remove_dir = os.path.join(os.path.join(read_dir, save_name_list[i]), 'noise_0//chosen')
            shutil.rmtree(remove_dir)
            check_existence(remove_dir)
        for index_name in range(len(name_list)):
        #for i in range(1):
            name_ = name_list[index_name]
            index_min = df['{}'.format(name_)][0]
            index_max = df['{}'.format(name_)][2]
            read_dir_folder = os.path.join(os.path.join(read_dir, save_name_list[index_name]), 'noise_0//ROI')
            save_dir_chosen = os.path.join(os.path.join(read_dir, save_name_list[index_name]), 'noise_0//chosen')
            file_list = natsort.natsorted(os.listdir(read_dir_folder))
            index_min = [i for i, x in enumerate(file_list) if x.find('{}_'.format(index_min)) == 0]
            index_max = [i for i, x in enumerate(file_list) if x.find('{}_'.format(index_max)) == 0]
            temp_index = name_.find('_')
            cri = name_[:temp_index]
            org = name_[temp_index+1:name_.find('_', temp_index+1)]
            save_dir_folder = os.path.join(save_dir_chosen, '{}_{}'.format(org, cri))
            check_existence(save_dir_folder)
            for j in range(len(index_min)):
                if cri == 'mae':
                    shutil.copy(os.path.join(read_dir_folder, file_list[index_min[j]]), os.path.join(save_dir_folder, file_list[index_min[j]]))
                elif cri == 'SSIM':
                    shutil.copy(os.path.join(read_dir_folder, file_list[index_max[j]]), os.path.join(save_dir_folder, file_list[index_max[j]]))

    if 0:
        read_dir = r'D:\CQL\codes\microscopy_decouple\evaluation\DSRM\SIM_synthetic_data\MAE_SSIM.csv'
        save_dir = r'D:\CQL\codes\microscopy_decouple\evaluation\DSRM\SIM_synthetic_data\MAE_SSIM_sta.csv'
        name_list = [
        'mae_CCPS_CCPS_ER', 'mae_ER_CCPS_ER', 'SSIM_CCPS_CCPS_ER', 'SSIM_ER_CCPS_ER', 'mae_whole_CCPS_ER', 'SSIM_whole_CCPS_ER', 
        'mae_CCPS_CCPS_Micro', 'mae_Micro_CCPS_Micro', 'SSIM_CCPS_CCPS_Micro', 'SSIM_Micro_CCPS_Micro', 'mae_whole_CCPS_Micro', 'SSIM_whole_CCPS_Micro', 
        'mae_CCPS_CCPS_F-actin', 'mae_F-actin_CCPS_F-actin', 'SSIM_CCPS_CCPS_F-actin', 'SSIM_F-actin_CCPS_F-actin', 'mae_whole_CCPS_F-actin', 'SSIM_whole_CCPS_F-actin', 
        'mae_ER_ER_Micro', 'mae_Micro_ER_Micro', 'SSIM_ER_ER_Micro', 'SSIM_Micro_ER_Micro', 'mae_whole_ER_Micro', 'SSIM_whole_ER_Micro', 
        'mae_CCPS_CCPS_ER_Micro', 'mae_ER_CCPS_ER_Micro', 'mae_Micro_CCPS_ER_Micro', 'SSIM_CCPS_CCPS_ER_Micro', 'SSIM_ER_CCPS_ER_Micro', 'SSIM_Micro_CCPS_ER_Micro', 'mae_whole_CCPS_ER_Micro', 'SSIM_whole_CCPS_ER_Micro'
        'mae_CCPS_CCPS_ER_F-actin', 'mae_ER_CCPS_ER_F-actin', 'mae_F-actin_CCPS_ER_Micro', 'SSIM_CCPS_CCPS_ER_F-actin', 'SSIM_ER_CCPS_ER_F-actin', 'SSIM_F-actin_CCPS_ER_Micro', 'mae_whole_CCPS_ER_F-actin', 'SSIM_whole_CCPS_ER_F-actin', 
        #'mae_CCPS_CCPS_Micro_F-actin', 'mae_Micro_CCPS_Micro_F-actin', 'mae_F-actin_CCPS_Micro_F-actin', 'SSIM_CCPS_CCPS_Micro_F-actin', 'SSIM_Micro_CCPS_Micro_F-actin', 'SSIM_F-actin_CCPS_Micro_F-actin', 
        #'mae_ER_ER_Micro_F-actin', 'mae_Micro_ER_Micro_F-actin', 'mae_F-actin_ER_Micro_F-actin', 'SSIM_ER_ER_Micro_F-actin', 'SSIM_Micro_ER_Micro_F-actin', 'SSIM_F-actin_ER_Micro_F-actin', 
        ]
        df = find_max_SSIM(read_dir=read_dir, save_dir=save_dir, name_list=name_list)

        read_dir = r'D:\CQL\codes\microscopy_decouple\evaluation\DSRM\SIM_synthetic_data'
        save_name_list = [
            'CCPS_ER', 'CCPS_ER','CCPS_ER','CCPS_ER', 'CCPS_ER', 'CCPS_ER', 
            'CCPS_Micro', 'CCPS_Micro', 'CCPS_Micro', 'CCPS_Micro', 'CCPS_Micro', 'CCPS_Micro', 
            'CCPS_F-actin', 'CCPS_F-actin', 'CCPS_F-actin', 'CCPS_F-actin', 'CCPS_F-actin', 'CCPS_F-actin', 
            'ER_F-actin', 'ER_F-actin', 'ER_F-actin', 'ER_F-actin', 'ER_F-actin', 'ER_F-actin', 
            'Micro_F-actin', 'Micro_F-actin', 'Micro_F-actin', 'Micro_F-actin', 'Micro_F-actin', 'Micro_F-actin', 
            'ER_Micro', 'ER_Micro', 'ER_Micro', 'ER_Micro', 'ER_Micro', 'ER_Micro', 
            'CCPS_ER_Micro', 'CCPS_ER_Micro', 'CCPS_ER_Micro', 'CCPS_ER_Micro', 'CCPS_ER_Micro', 'CCPS_ER_Micro', 'CCPS_ER_Micro', 'CCPS_ER_Micro', 
            'CCPS_ER_F-actin', 'CCPS_ER_F-actin', 'CCPS_ER_F-actin', 'CCPS_ER_F-actin', 'CCPS_ER_F-actin', 'CCPS_ER_F-actin', 'CCPS_ER_F-actin', 'CCPS_ER_F-actin', 
            #'CCPS_Micro_F-actin', 'CCPS_Micro_F-actin', 'CCPS_Micro_F-actin', 'CCPS_Micro_F-actin', 'CCPS_Micro_F-actin', 'CCPS_Micro_F-actin', 
            #'ER_Micro_F-actin', 'ER_Micro_F-actin', 'ER_Micro_F-actin', 'ER_Micro_F-actin', 'ER_Micro_F-actin', 'ER_Micro_F-actin'
            ]
            
        for i in range(len(save_name_list)):
            remove_dir = os.path.join(os.path.join(read_dir, save_name_list[i]), 'noise_0//chosen')
            try:
                shutil.rmtree(remove_dir)
            except:
                pass
            check_existence(remove_dir)
        for index_name in range(len(name_list)):
        #for i in range(1):
            name_ = name_list[index_name]
            index_min = df['{}'.format(name_)][0]
            index_max = df['{}'.format(name_)][2]
            read_dir_folder = os.path.join(os.path.join(read_dir, save_name_list[index_name]), 'noise_0//ROI')
            save_dir_chosen = os.path.join(os.path.join(read_dir, save_name_list[index_name]), 'noise_0//chosen')
            file_list = natsort.natsorted(os.listdir(read_dir_folder))
            index_min = [i for i, x in enumerate(file_list) if x.find('{}_'.format(index_min)) == 0]
            index_max = [i for i, x in enumerate(file_list) if x.find('{}_'.format(index_max)) == 0]
            temp_index = name_.find('_')
            cri = name_[:temp_index]
            org = name_[temp_index+1:name_.find('_', temp_index+1)]
            save_dir_folder = os.path.join(save_dir_chosen, '{}_{}'.format(org, cri))
            check_existence(save_dir_folder)
            for j in range(len(index_min)):
                
                if cri == 'mae':
                    shutil.copy(os.path.join(read_dir_folder, file_list[index_min[j]]), os.path.join(save_dir_folder, file_list[index_min[j]]))
                elif cri == 'SSIM':
                    shutil.copy(os.path.join(read_dir_folder, file_list[index_max[j]]), os.path.join(save_dir_folder, file_list[index_max[j]]))
